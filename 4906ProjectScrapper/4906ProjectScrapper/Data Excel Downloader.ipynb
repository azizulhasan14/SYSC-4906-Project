# %%
from openpyxl import load_workbook


import requests
import wget
import os

data_file = '/Users/agb/4906ProjectScrapper/Test West Kelowna.xlsx'

# Load the entire workbook.
wb = load_workbook(data_file)

print(wb.sheetnames)

#Create directories to store files from the datasheet    
dataset = '/Users/agb/4906ProjectScrapper/Downloaded Data'
try:
    os.mkdir(dataset)
except OSError:
    print ("Creation of the directory %s failed" % dataset)
else:
    print ("Successfully created the directory %s " % dataset)
    
# List all the sheets in the file.
print("Found the following worksheets:")
for sheet in wb:
    
    # Print out current sheet being worked on
    print(wb.active)
    ws = sheet
    
    # Assign Data From the Current Spreadsheeet
    PN_PT = ws['B1'].value
    Coverage = ws['B2'].value
    Dataset_Name_EN = ws['B3'].value
    Dataset_Name_FR = ws['B4'].value
    Static_GTFS = ws['B5'].value
    Realtime_GTFS = ws['B6'].value
    CSV = ws['B7'].value
    KML = ws['B8'].value
    Shapefile_SHP = ws['B9'].value
    GeoJson = ws['B10'].value
    PDF_orjpg_Map = ws['B11'].value
    Responsible_department_authority_contact_information_phone = ws['B12'].value
    Responsible_department_authority_contact_information_EMAIL = ws['B13'].value
    Metadata_EN = ws['B14'].value
    Metadata_FR = ws['B15'].value
    Url_Static_GTFS_ = ws['B16'].value
    Url_Realtime_GTFS_ = ws['B17'].value
    Url_CSV = ws['B18'].value
    Url_KML = ws['B19'].value
    Url_Shapefile_SHP = ws['B20'].value
    Url_GeoJson = ws['B21'].value
    Url_PDF_or_jpg_Map = ws['B22'].value
    Description_EN = ws['B23'].value
    Description_FR = ws['B24'].value
    Data_Currency = ws['B25'].value
    Data_Confidence_Level = ws['B26'].value
    Data_Available = ws['B27'].value
    
    path = "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/StaticGTFS"
    try:
        os.makedirs(path)
    except OSError:
        print ("Creation of the directory %s failed" % path)
    else:
        print ("Successfully created the directory %s" % path)
    if Url_Static_GTFS_ != 'n/a':
        url = Url_Static_GTFS_
        wget.download(url, "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/StaticGTFS/StaticGTFS.zip")
    
    path = "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/Realtime_GTFS"
    try:
        os.makedirs(path)
    except OSError:
        print ("Creation of the directory %s failed" % path)
    else:
        print ("Successfully created the directory %s" % path)
    if Url_Realtime_GTFS_ != 'n/a':
        url = Url_Realtime_GTFS_
        wget.download(url, "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/Realtime_GTFS/Realtime_GTFS.bin")
        
    path = "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/CSV"
    try:
        os.makedirs(path)
    except OSError:
        print ("Creation of the directory %s failed" % path)
    else:
        print ("Successfully created the directory %s" % path)
    if Url_CSV != 'n/a':
        url = Url_CSV
        wget.download(url, "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/CSV/CSV.csv")

    path = "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/KML"
    try:
        os.makedirs(path)
    except OSError:
        print ("Creation of the directory %s failed" % path)
    else:
        print ("Successfully created the directory %s" % path)
    if Url_KML != 'n/a':
        url = Url_KML
        wget.download(url, "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/KML/KML.kml")
    
    path = "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/Shapefile_SHP"
    try:
        os.makedirs(path)
    except OSError:
        print ("Creation of the directory %s failed" % path)
    else:
        print ("Successfully created the directory %s" % path)
    if Url_Shapefile_SHP != 'n/a':
        url =  Url_Shapefile_SHP
        wget.download(url, "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/Shapefile_SHP/Shapefile_SHP.zip")
    
    path = "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/GeoJson"
    try:
        os.makedirs(path)
    except OSError:
        print ("Creation of the directory %s failed" % path)
    else:
        print ("Successfully created the directory %s" % path)
    if Url_GeoJson != 'n/a':
        url =  Url_GeoJson
        wget.download(url, "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/GeoJson/GeoJson.zip")
    
    path = "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/PDF_orjpg_Map"
    try:
        os.makedirs(path)
    except OSError:
        print ("Creation of the directory %s failed" % path)
    else:
        print ("Successfully created the directory %s" % path)
    if Url_PDF_or_jpg_Map != 'n/a':
        url =  Url_PDF_or_jpg_Map
        wget.download(url, "/Users/agb/4906ProjectScrapper/Downloaded Data/" + sheet.title + "/PDF_orjpg_Map/Pdf.pdf")
# Out:
# ['West Kelowna , BC', 'Thetford Mines, QC']
# Successfully created the directory /Users/agb/4906ProjectScrapper/Downloaded Data
# Found the following worksheets:
# <Worksheet "Thetford Mines, QC">
# Successfully created the directory /Users/agb/4906ProjectScrapper/Downloaded Data/West Kelowna , BC/StaticGTFS
# 100% [......................................................] 1193807 / 1193807Successfully created the directory /Users/agb/4906ProjectScrapper/Downloaded Data/West Kelowna , BC/Realtime_GTFS
# 100% [............................................................] 5222 / 5222Successfully created the directory /Users/agb/4906ProjectScrapper/Downloaded Data/West Kelowna , BC/CSV
# 100% [........................................................] 124354 / 124354Successfully created the directory /Users/agb/4906ProjectScrapper/Downloaded Data/West Kelowna , BC/KML
# ...
